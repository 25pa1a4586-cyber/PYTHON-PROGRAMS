# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4586-cyber/PYTHON-PROGRAMS/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a python program to check if a key exist in a dictonary or not
my_dict = {"name": "shalini", "age": 19, "course": "AIDS"}
key = input("enter key:")
if key in my_dict:
  print("yes")
else:
    print("no")
# Out:
# enter key:age
# yes

# %%
#write a program to sum all items in a given dictionary
d={1:2}
