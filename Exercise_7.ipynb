# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4586-cyber/PYTHON-PROGRAMS/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TUPLES
t = (10, 20, 30, 40)
print(t)
# Out:
# (10, 20, 30, 40)

# %%
#operations
t1 = (1,2,3,)
t2 = (4,5,6)
print( t1)
print(t2)
print(t1+t2)
print(t1*7)
print(2 in t1)
print(7 in t2)
print(t.count(4))
print("Slicing:",t1[1:2])
# Out:
# (1, 2, 3)
# (4, 5, 6)
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3)
# True
# False
# 0
# Slicing: (2,)

# %%
#functions
print(sum(t1))
print(max(t2))
print(len(t1))
print(min(t2))
# Out:
# 6
# 6
# 3
# 4

# %%
#methods
t = (10,20,30,40)
print("Count of 20:", t.count(20))
print("Indexof 30:", t.index(30))
# Out:
# Count of 20: 1
# Indexof 30: 2

# %%
#zip
t1 = (1,2,3)
t2 = (4,5,6)
print(tuple((zip(t1,t2))))
# Out:
# ((1, 4), (2, 5), (3, 6))

# %%
#write a program to count the number of vowels in a srting (No control #flow allowed).
s = str(input("Enter a string:"))
s1 = s.lower()
vowels_count=s1.count("a")+s1.count("e")+s1.count("i")+s1.count("o")+s1.count("u")
print("the no of vowels are",vowels_count)
# Out:
# Enter a string:shalini
# the no of vowels are 3

# %%
#write a program to create tuples(name,age,address,college) for at least
#two members and concatenate the tuples and print the concatenated tuples.
student1=("Abhi",20,"bvrm","vit")
student2=("Shalini",20,"vizag","vit")
print(student1+student2)
# Out:
# ('Abhi', 20, 'bvrm', 'vit', 'Shalini', 20, 'vizag', 'vit')

# %%
#SETS
A = {1,2,3}
B = {3,4,5}
#operations
print(A|B) #union
print(A&B) #intersection
print(A-B) #difference
print(A^B) #symmetric difference

#methods
s = {14, 15, "abhi", "shalini", (1,2,3)}
print(s)
s.add(18) #add
print(s)
s2 = {22,33} #update
s.update(s2)
print(s)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}
# {'abhi', (1, 2, 3), 'shalini', 14, 15}
# {18, 'abhi', (1, 2, 3), 'shalini', 14, 15}
# {33, 18, 22, 'abhi', (1, 2, 3), 'shalini', 14, 15}
