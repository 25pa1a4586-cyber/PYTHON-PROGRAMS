# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4586-cyber/PYTHON-PROGRAMS/blob/main/Exercise_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L1=[1,2,3]
L2=[3,4,5]
print(L1+L2)
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
L1=[1,4,14,15,17,15.4,"hello","name"]
L2=[100,145,300]
print(L1+L2)#concatenation
print(L1*3)#repetition
print(L1[4])#indexing,prints element at 5th index
print(100 in L2)#checks 100 present in list L2 or not
print(L1[2:7])#slicing,prints elements from 2nd index to 7th index
print(L1[::-1])#prints elements in reverse order
print(L1[-7:-1])
for i in L2:
  print(i)
# Out:
# [1, 4, 14, 15, 17, 15.4, 'hello', 'name', 100, 145, 300]
# [1, 4, 14, 15, 17, 15.4, 'hello', 'name', 1, 4, 14, 15, 17, 15.4, 'hello', 'name', 1, 4, 14, 15, 17, 15.4, 'hello', 'name']
# 17
# True
# [14, 15, 17, 15.4, 'hello']
# ['name', 'hello', 15.4, 17, 15, 14, 4, 1]
# [4, 14, 15, 17, 15.4, 'hello']
# 100
# 145
# 300
